# %%
import sys
sys.path.append('/home/vivek/Documents/Workshop/lit-llama')

# %%
import os
import time

import lightning as L
import numpy as np
import torch

from generate import generate
# Out:
# /home/vivek/anaconda3/envs/transformers/lib/python3.10/site-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: libtorch_cuda_cu.so: cannot open shared object file: No such file or directory
#   warn(f"Failed to load image Python extension: {e}")
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 4
#       1 import os
#       2 import time
# ----> 4 import lightning as L
#       5 import numpy as np
#       6 import torch
#
# File ~/anaconda3/envs/transformers/lib/python3.10/site-packages/lightning/__init__.py:27
#      25 from lightning.fabric.fabric import Fabric  # noqa: E402
#      26 from lightning.fabric.utilities.seed import seed_everything  # noqa: E402
# ---> 27 from lightning.pytorch.callbacks import Callback  # noqa: E402
#      28 from lightning.pytorch.core import LightningDataModule, LightningModule  # noqa: E402
#      29 from lightning.pytorch.trainer import Trainer  # noqa: E402
#
# File ~/anaconda3/envs/transformers/lib/python3.10/site-packages/lightning/pytorch/__init__.py:26
#      23     _logger.propagate = False
#      25 from lightning.fabric.utilities.seed import seed_everything  # noqa: E402
# ---> 26 from lightning.pytorch.callbacks import Callback  # noqa: E402
#      27 from lightning.pytorch.core import LightningDataModule, LightningModule  # noqa: E402
#      28 from lightning.pytorch.trainer import Trainer  # noqa: E402
#
# File ~/anaconda3/envs/transformers/lib/python3.10/site-packages/lightning/pytorch/callbacks/__init__.py:14
#       1 # Copyright The Lightning AI team.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)
#      12 # See the License for the specific language governing permissions and
#      13 # limitations under the License.
# ---> 14 from lightning.pytorch.callbacks.batch_size_finder import BatchSizeFinder
#      15 from lightning.pytorch.callbacks.callback import Callback
#      16 from lightning.pytorch.callbacks.checkpoint import Checkpoint
#
# File ~/anaconda3/envs/transformers/lib/python3.10/site-packages/lightning/pytorch/callbacks/batch_size_finder.py:24
#      21 from typing import Optional
#      23 import lightning.pytorch as pl
# ---> 24 from lightning.pytorch.callbacks.callback import Callback
#      25 from lightning.pytorch.tuner.batch_size_scaling import _scale_batch_size
#      26 from lightning.pytorch.utilities.exceptions import _TunerExitException, MisconfigurationException
#
# File ~/anaconda3/envs/transformers/lib/python3.10/site-packages/lightning/pytorch/callbacks/callback.py:25
#      22 from torch.optim import Optimizer
#      24 import lightning.pytorch as pl
# ---> 25 from lightning.pytorch.utilities.types import STEP_OUTPUT
#      28 class Callback:
#      29     r"""
#      30     Abstract base class used to build new callbacks.
#      31
#      32     Subclass this class and override any of the relevant hooks
#      33     """
#
# File ~/anaconda3/envs/transformers/lib/python3.10/site-packages/lightning/pytorch/utilities/types.py:25
#      23 import torch
#      24 from torch import Tensor
# ---> 25 from torchmetrics import Metric
#      27 from lightning.fabric.utilities.types import _TORCH_LRSCHEDULER, LRScheduler, ProcessGroup, ReduceLROnPlateau
#      29 _NUMBER = Union[int, float]
#
# File ~/anaconda3/envs/transformers/lib/python3.10/site-packages/torchmetrics/__init__.py:14
#      11 _PACKAGE_ROOT = os.path.dirname(__file__)
#      12 _PROJECT_ROOT = os.path.dirname(_PACKAGE_ROOT)
# ---> 14 from torchmetrics import functional  # noqa: E402
#      15 from torchmetrics.aggregation import CatMetric, MaxMetric, MeanMetric, MinMetric, SumMetric  # noqa: E402
#      16 from torchmetrics.audio import (  # noqa: E402
#      17     PermutationInvariantTraining,
#      18     ScaleInvariantSignalDistortionRatio,
#    (...)
#      21     SignalNoiseRatio,
#      22 )
#
# File ~/anaconda3/envs/transformers/lib/python3.10/site-packages/torchmetrics/functional/__init__.py:82
#      80 from torchmetrics.functional.retrieval.recall import retrieval_recall
#      81 from torchmetrics.functional.retrieval.reciprocal_rank import retrieval_reciprocal_rank
# ---> 82 from torchmetrics.functional.text.bleu import bleu_score
#      83 from torchmetrics.functional.text.cer import char_error_rate
#      84 from torchmetrics.functional.text.chrf import chrf_score
#
# File ~/anaconda3/envs/transformers/lib/python3.10/site-packages/torchmetrics/functional/text/__init__.py:30
#      27 from torchmetrics.utilities.imports import _NLTK_AVAILABLE, _TRANSFORMERS_AVAILABLE
#      29 if _TRANSFORMERS_AVAILABLE:
# ---> 30     from torchmetrics.functional.text.bert import bert_score  # noqa: F401
#      31     from torchmetrics.functional.text.infolm import infolm  # noqa: F401
#      33 if _NLTK_AVAILABLE:
#
# File ~/anaconda3/envs/transformers/lib/python3.10/site-packages/torchmetrics/functional/text/bert.py:24
#      21 from torch.nn import Module
#      22 from torch.utils.data import DataLoader
# ---> 24 from torchmetrics.functional.text.helper_embedding_metric import (
#      25     TextDataset,
#      26     TokenizedDataset,
#      27     _check_shape_of_model_output,
#      28     _get_progress_bar,
#      29     _input_data_collator,
#      30     _output_data_collator,
#      31     _process_attention_mask_for_special_tokens,
#      32 )
#      33 from torchmetrics.utilities.checks import _SKIP_SLOW_DOCTEST, _try_proceed_with_timeout
#      34 from torchmetrics.utilities.imports import _TQDM_AVAILABLE, _TRANSFORMERS_AVAILABLE
#
# File ~/anaconda3/envs/transformers/lib/python3.10/site-packages/torchmetrics/functional/text/helper_embedding_metric.py:26
#      23 from torchmetrics.utilities.imports import _TQDM_AVAILABLE, _TRANSFORMERS_AVAILABLE
#      25 if _TRANSFORMERS_AVAILABLE:
# ---> 26     from transformers import AutoModelForMaskedLM, AutoTokenizer, PreTrainedModel, PreTrainedTokenizerBase
#      27 else:
#      28     PreTrainedModel = PreTrainedTokenizerBase = None  # type: ignore
#
# File ~/.local/lib/python3.10/site-packages/transformers/__init__.py:26
#      23 from typing import TYPE_CHECKING
#      25 # Check the dependencies satisfy the minimal versions required.
# ---> 26 from . import dependency_versions_check
#      27 from .utils import (
#      28     OptionalDependencyNotAvailable,
#      29     _LazyModule,
#    (...)
#      42     logging,
#      43 )
#      46 logger = logging.get_logger(__name__)  # pylint: disable=invalid-name
#
# File ~/.local/lib/python3.10/site-packages/transformers/dependency_versions_check.py:17
#      14 import sys
#      16 from .dependency_versions_table import deps
# ---> 17 from .utils.versions import require_version, require_version_core
#      20 # define which module versions we always want to check at run time
#      21 # (usually the ones defined in `install_requires` in setup.py)
#      22 #
#      23 # order specific notes:
#      24 # - tqdm must be checked before tokenizers
#      26 pkgs_to_check_at_runtime = "python tqdm regex requests packaging filelock numpy tokenizers".split()
#
# File ~/.local/lib/python3.10/site-packages/transformers/utils/__init__.py:30
#      21 from .constants import IMAGENET_DEFAULT_MEAN, IMAGENET_DEFAULT_STD, IMAGENET_STANDARD_MEAN, IMAGENET_STANDARD_STD
#      22 from .doc import (
#      23     add_code_sample_docstrings,
#      24     add_end_docstrings,
#    (...)
#      28     replace_return_docstrings,
#      29 )
# ---> 30 from .generic import (
#      31     ContextManagers,
#      32     ExplicitEnum,
#      33     ModelOutput,
#      34     PaddingStrategy,
#      35     TensorType,
#      36     cached_property,
#      37     can_return_loss,
#      38     expand_dims,
#      39     find_labels,
#      40     flatten_dict,
#      41     is_jax_tensor,
#      42     is_numpy_array,
#      43     is_tensor,
#      44     is_tf_tensor,
#      45     is_torch_device,
#      46     is_torch_dtype,
#      47     is_torch_tensor,
#      48     reshape,
#      49     squeeze,
#      50     tensor_size,
#      51     to_numpy,
#      52     to_py_obj,
#      53     transpose,
#      54     working_or_temp_dir,
#      55 )
#      56 from .hub import (
#      57     CLOUDFRONT_DISTRIB_PREFIX,
#      58     DISABLE_TELEMETRY,
#    (...)
#      84     send_example_telemetry,
#      85 )
#      86 from .import_utils import (
#      87     ENV_VARS_TRUE_AND_AUTO_VALUES,
#      88     ENV_VARS_TRUE_VALUES,
#    (...)
#     166     torch_version,
#     167 )
#
# File ~/.local/lib/python3.10/site-packages/transformers/utils/generic.py:29
#      25 from typing import Any, ContextManager, List, Tuple
#      27 import numpy as np
# ---> 29 from .import_utils import is_flax_available, is_tf_available, is_torch_available, is_torch_fx_proxy
#      32 if is_flax_available():
#      33     import jax.numpy as jnp
#
# File ~/.local/lib/python3.10/site-packages/transformers/utils/import_utils.py:393
#     391 _torch_fx_available = _torch_onnx_dict_inputs_support_available = False
#     392 if _torch_available:
# --> 393     torch_version = version.parse(importlib_metadata.version("torch"))
#     394     _torch_fx_available = (torch_version.major, torch_version.minor) >= (
#     395         TORCH_FX_REQUIRED_VERSION.major,
#     396         TORCH_FX_REQUIRED_VERSION.minor,
#     397     )
#     399     _torch_onnx_dict_inputs_support_available = torch_version >= TORCH_ONNX_DICT_INPUTS_MINIMUM_VERSION
#
# File ~/.local/lib/python3.10/site-packages/packaging/version.py:52, in parse(version)
#      43 def parse(version: str) -> "Version":
#      44     """Parse the given version string.
#      45
#      46     >>> parse('1.0.dev1')
#    (...)
#      50     :raises InvalidVersion: When the version string is not a valid version.
#      51     """
# ---> 52     return Version(version)
#
# File ~/.local/lib/python3.10/site-packages/packaging/version.py:195, in Version.__init__(self, version)
#     184 """Initialize a Version object.
#     185
#     186 :param version:
#    (...)
#     191     exception will be raised.
#     192 """
#     194 # Validate the version and parse it into pieces
# --> 195 match = self._regex.search(version)
#     196 if not match:
#     197     raise InvalidVersion(f"Invalid version: '{version}'")
#
# TypeError: expected string or bytes-like object

# %% [markdown]
# Lora finetuning
